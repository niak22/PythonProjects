# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
ds = pd.read_csv("train.csv")

# %%
ds.head(10)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0         0       3    male  22.0      1      0   7.2500        S   Third
# 1         1       1  female  38.0      1      0  71.2833        C   First
# 2         1       3  female  26.0      0      0   7.9250        S   Third
# 3         1       1  female  35.0      1      0  53.1000        S   First
# 4         0       3    male  35.0      0      0   8.0500        S   Third
# 5         0       3    male   NaN      0      0   8.4583        Q   Third
# 6         0       1    male  54.0      0      0  51.8625        S   First
# 7         0       3    male   2.0      3      1  21.0750        S   Third
# 8         1       3  female  27.0      0      2  11.1333        S   Third
# 9         1       2  female  14.0      1      0  30.0708        C  Second
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# ...

# %%
ds.boxplot(by ='survived', column =['age'], grid = False)
# Out:
# <Axes: title={'center': 'age'}, xlabel='survived'>

# %%
ds['survived'].value_counts().plot.bar()
plt.ylabel('Count')
plt.title('survivors and fatalities Count')
plt.show()

# %%
#Question 5
#Produce a horizontal bar chart showing all passenger classes, ordered with smallest number at top and largest at bottom.

ds.groupby("pclass").size().sort_values(ascending=False).plot(kind='barh')
# Out:
# <Axes: ylabel='pclass'>

# %%
#Question 6
#Produce a density plot for number of siblings (SibSp).


ds.sibsp.plot.density(color='green') 
plt.title('Density plot for siblings') 
plt.show()

# %%
#Question 7
#Try to personalise the graphs that you’ve produced.

# %%
#Question 3
#Produce a stacked bar chart showing the number of each gender in each passenger class.

gender_counts = ds.groupby(['pclass', 'sex']).size().unstack().fillna(0)
ax = gender_counts.plot(kind='bar', stacked=True)
plt.title('Passenger Gender Distribution by Class')
plt.xlabel('Passenger Class')
plt.ylabel('Count')
plt.legend(title='Gender', labels=['Female', 'Male'])

plt.show()

#Question 4
#Produce a heatmap showing the correlation between each numerical variable. What shows a strong correlation?

#Question 5
#Produce a single scatter plot showing age and passenger class as well as age and number of siblings, different symbols should be used to represent the two different comparisons.

# %%
#Question 4
#Produce a heatmap showing the correlation between each numerical variable. What shows a strong correlation?

# Select only the numerical columns
numeric_columns = ds.select_dtypes(include=['float64', 'int64'])

# Compute the correlation matrix
correlation_matrix = numeric_columns.corr()

sns.heatmap(correlation_matrix, annot=True)

# Set the title
plt.title('Correlation Heatmap')

plt.show()

# %%
corr = df.corr()
sns.heatmap(corr)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[89], line 1
# ----> 1 corr = df.corr()
#       2 sns.heatmap(corr)
#       3 plt.show()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:10054, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10052 cols = data.columns
#   10053 idx = cols.copy()
# > 10054 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10056 if method == "pearson":
#   10057     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:1838, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1836 if dtype is not None:
#    1837     dtype = np.dtype(dtype)
# -> 1838 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1839 if result.dtype is not dtype:
# ...
